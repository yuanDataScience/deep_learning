# %%
# !split -b 50m allfiles.tar.gz allfiles.tar.gz.part.

# %%
# !tar chvfz allfiles.tar.gz *
# Out:
# Autonomous driving application - Car detection - v1.ipynb
# Autonomous driving application - Car detection - v2.ipynb
# Autonomous driving application - Car detection - v3.ipynb
# Autonomous_driving_application_Car_detection_v3a.ipynb
# Drive.ai Dataset Sample LICENSE
# LICENSE
# Untitled.ipynb
# __pycache__/
# __pycache__/yolo_utils.cpython-36.pyc
# font/
# font/FiraMono-Medium.otf
# font/SIL Open Font License.txt
# images/
# images/0010.jpg
# images/0089.jpg
# images/0001.jpg
# images/0100.jpg
# images/0098.jpg
# images/0117.jpg
# images/0036.jpg
# images/0072.jpg
# images/0054.jpg
# images/0018.jpg
# images/0090.jpg
# images/0045.jpg
# images/0009.jpg
# images/0081.jpg
# images/0063.jpg
# images/0108.jpg
# images/0027.jpg
# images/0032.jpg
# images/0113.jpg
# images/0050.jpg
# images/0014.jpg
# images/0041.jpg
# images/0005.jpg
# images/0023.jpg
# images/0104.jpg
# images/0076.jpg
# images/0058.jpg
# images/0094.jpg
# images/0049.jpg
# images/0085.jpg
# images/0067.jpg
# ...
